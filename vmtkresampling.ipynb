# %%
import subprocess
import glob

files = glob.glob("d:/!BraVa_src/src/ModeDecomposition/fine_tube/CenterlineExtend_correctindex/extended_centerline/*.vtk")

for i in range(len(files)):
    ifile = files[i].replace("/", "\\\\")
    # print (ifile)
    ofile = ifile.replace("extended_centerline", "resampled_centerline")
    # print (ofile)
    # subprocess.run("vmtk vmtkcenterlineresampling -ifile {} -ofile {} -length 1.0".format(ifile,ofile), shell=True)
    print ("vmtkcenterlineresampling -ifile {} -ofile {} -length 1.0".format(ifile,ofile))
# Out:
# vmtkcenterlineresampling -ifile d:\\!BraVa_src\\src\\ModeDecomposition\\fine_tube\\CenterlineExtend_correctindex\\extended_centerline\BG0002_Left_extended.vtk -ofile d:\\!BraVa_src\\src\\ModeDecomposition\\fine_tube\\CenterlineExtend_correctindex\\resampled_centerline\BG0002_Left_extended.vtk -length 1.0
# vmtkcenterlineresampling -ifile d:\\!BraVa_src\\src\\ModeDecomposition\\fine_tube\\CenterlineExtend_correctindex\\extended_centerline\BG0002_Right_extended.vtk -ofile d:\\!BraVa_src\\src\\ModeDecomposition\\fine_tube\\CenterlineExtend_correctindex\\resampled_centerline\BG0002_Right_extended.vtk -length 1.0
# vmtkcenterlineresampling -ifile d:\\!BraVa_src\\src\\ModeDecomposition\\fine_tube\\CenterlineExtend_correctindex\\extended_centerline\BG0014_Left_extended.vtk -ofile d:\\!BraVa_src\\src\\ModeDecomposition\\fine_tube\\CenterlineExtend_correctindex\\resampled_centerline\BG0014_Left_extended.vtk -length 1.0
# ...
